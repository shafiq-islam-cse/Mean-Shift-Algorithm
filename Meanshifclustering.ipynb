# %%
# Code help:https://scikit-learn.org/stable/modules/generated/sklearn.cluster.MeanShift.html
# Mean shift clsustering basic
from sklearn.cluster import MeanShift
import numpy as np
X = np.array([[1, 1], [2, 1], [1, 0],
               [4, 7], [3, 5], [3, 6]])
print("Generated data :")
print("Features Target")
print(X)

clustering = MeanShift(bandwidth=2).fit(X)
print("Features of the focused MS clustering is :")
clustering
MeanShift(bandwidth=2)

print("Target Data label are :")
target_data_label=clustering.labels_
print(target_data_label)

#array([1, 1, 1, 0, 0, 0])
print("Prediction of [[0,0],[5,5]] is :")
p=clustering.predict([[0, 0], [5, 5]])
print(p)
#array([1, 0])
# Out:
# Generated data :
# Features Target
# [[1 1]
#  [2 1]
#  [1 0]
#  [4 7]
#  [3 5]
#  [3 6]]
# Features of the focused MS clustering is :
# Target Data label are :
# [1 1 1 0 0 0]
# Prediction of [[0,0],[5,5]] is :
# [1 0]

# %%
# Help of coding: https://github.com/PacktWorkshops/The-Machine-Learning-Workshop/blob/master/Chapter02/Exercise2.03/Exercise2_03.ipynb

from sklearn.cluster import MeanShift
import numpy as np
from sklearn.cluster import MeanShift
data = pd.read_csv("/content/drive/MyDrive/Research Documents/Updated Work/8. Rahim vai task for vehicle condition monitoring/Rahim vai Phd task Ata University Finland/data7.csv")
print("Data sample is\n",data)
est_meanshift = MeanShift(0.5)
est_meanshift.fit(data)
pred_meanshift = est_meanshift.predict(data)

plt.scatter(data.iloc[:,0], data.iloc[:,1], c=pred_meanshift)
plt.show()

# Histogram
plt.hist(data.iloc[:,0])
plt.show()
# Out:
# Data sample is
#           theta         r
# 0     0.881226  2.323627
# 1     1.255041  2.684993
# 2     1.657993  3.275960
# 3     2.499764  3.949045
# 4     1.365699  3.325664
# ...        ...       ...
# 1195  2.116992  5.703093
# 1196  1.924023  5.159695
# 1197  1.703855  4.594707
# 1198  0.927647  4.245107
# 1199  2.334062  5.365983
#
# [1200 rows x 2 columns]

# %%
# Finding Mean and covarience by Mean shift clustering
#

# %%
# 
# Long mean shift
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs

# #############################################################################
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)
# #############################################################################

# Generate sample data
#data = pd.read_csv("/content/drive/MyDrive/Research Documents/Updated Work/8. Rahim vai task for vehicle condition monitoring/Rahim vai Phd task Ata University Finland/data7.csv")
#centers = [[1, 1], [-1, -1], [1, -1]]
#X, _ = data(n_samples=10000, centers=centers, cluster_std=0.6)
# #############################################################################
# Compute clustering with MeanShift
#X = pd.read_csv("/content/drive/MyDrive/Research Documents/Updated Work/8. Rahim vai task for vehicle condition monitoring/Rahim vai Phd task Ata University Finland/data7.csv")

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)

# #############################################################################
# Plot result
import matplotlib.pyplot as plt
from itertools import cycle

plt.figure(1)
plt.clf()

colors = cycle("bgrcmykbgrcmykbgrcmykbgrcmyk")
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + ".")
    plt.plot(
        cluster_center[0],
        cluster_center[1],
        "o",
        markerfacecolor=col,
        markeredgecolor="k",
        markersize=14,
    )
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
# Out:
# number of estimated clusters : 3
